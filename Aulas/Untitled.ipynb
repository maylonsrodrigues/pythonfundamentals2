# %%
print('esse é o print')
# Out:
# esse é o print

# %%
print('esse é o print')
# Out:
# esse é o print

# %%
import pandas as pd

# %%
df = pd.read_csv('dados/campeonato-brasileiro-full.csv')

# %%
df.shape
# Out:
# (7939, 13)

# %%
df.head(100)
# Out:
#    Horário      Dia        Data      Clube 1        Clube 2       Vencedor  \
# 0    16h00   Sábado  2000-07-29   Fluminense          Bahia     Fluminense
# 1    16h00   Sábado  2000-07-29        Vasco          Sport          Sport
# 2    16h00   Sábado  2000-07-29      Vitória      Palmeiras        Vitória
# 3    17h00  Domingo  2000-07-30  Botafogo-RJ    Atlético-MG              -
# 4    18h30  Domingo  2000-07-30    Juventude       Flamengo              -
# ..     ...      ...         ...          ...            ...            ...
# 95   16h00   Sábado  2000-09-02   Santa Cruz     Portuguesa              -
# 96   16h00   Sábado  2000-09-02   América-MG        Guarani     América-MG
# 97   15h45   Sábado  2000-09-02  Atlético-MG       Flamengo       Flamengo
# 98   16h00   Sábado  2000-09-02   Fluminense    Botafogo-RJ     Fluminense
# 99   15h45   Sábado  2000-09-02         Gama  Internacional  Internacional
#
# ...

# %%
df2 = df

# %%
df2.drop([0, 15]) #remove linhas
# Out:
#      Horário      Dia        Data        Clube 1      Clube 2       Vencedor  \
# 1      16h00   Sábado  2000-07-29          Vasco        Sport          Sport
# 2      16h00   Sábado  2000-07-29        Vitória    Palmeiras        Vitória
# 3      17h00  Domingo  2000-07-30    Botafogo-RJ  Atlético-MG              -
# 4      18h30  Domingo  2000-07-30      Juventude     Flamengo              -
# 5      16h00  Domingo  2000-07-30        Guarani   Santa Cruz              -
# ...      ...      ...         ...            ...          ...            ...
# 7934   17:00  Domingo  2019-12-08          Goiás       Grêmio          Goiás
# 7935   17:00  Domingo  2019-12-08  Internacional  Atlético-MG  Internacional
# 7936   17:00  Domingo  2019-12-08       Cruzeiro    Palmeiras      Palmeiras
# 7937   17:00  Domingo  2019-12-08         Santos     Flamengo         Santos
# 7938   17:00  Domingo  2019-12-08            CSA    São Paulo      São Paulo
#
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=7939, step=1)

# %%
df.cout
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-c0ae4439f49f> in <module>
# ----> 1 df.cout
#
# ~/pythonfundamentals2/venv/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cout'

# %%
df2.count()
# Out:
# Horário                  7582
# Dia                      7939
# Data                     7939
# Clube 1                  7939
# Clube 2                  7939
# Vencedor                 7939
# Rodada                   7939
# Arena                    7939
# Clube 1 Gols             7939
# Clube 2 Gols             7939
# Clube 1 Estado           7939
# Clube 2 Estado           7939
# Estado Clube Vencedor    7939
# dtype: int64

# %%
df2['Resultado'] = df2['Clube 1 Gols']

# %%
df2
# Out:
#      Horário      Dia        Data        Clube 1      Clube 2       Vencedor  \
# 0      16h00   Sábado  2000-07-29     Fluminense        Bahia     Fluminense
# 1      16h00   Sábado  2000-07-29          Vasco        Sport          Sport
# 2      16h00   Sábado  2000-07-29        Vitória    Palmeiras        Vitória
# 3      17h00  Domingo  2000-07-30    Botafogo-RJ  Atlético-MG              -
# 4      18h30  Domingo  2000-07-30      Juventude     Flamengo              -
# ...      ...      ...         ...            ...          ...            ...
# 7934   17:00  Domingo  2019-12-08          Goiás       Grêmio          Goiás
# 7935   17:00  Domingo  2019-12-08  Internacional  Atlético-MG  Internacional
# 7936   17:00  Domingo  2019-12-08       Cruzeiro    Palmeiras      Palmeiras
# 7937   17:00  Domingo  2019-12-08         Santos     Flamengo         Santos
# 7938   17:00  Domingo  2019-12-08            CSA    São Paulo      São Paulo
#
# ...

# %%
df.to_csv('novo aqrquivo.csv')

# %%
df.columns
# Out:
# Index(['Horário', 'Dia', 'Data', 'Clube 1', 'Clube 2', 'Vencedor', 'Rodada',
#        'Arena', 'Clube 1 Gols', 'Clube 2 Gols', 'Clube 1 Estado',
#        'Clube 2 Estado', 'Estado Clube Vencedor', 'Resultado'],
#       dtype='object')

# %%
df.apply(lambda x: x.replace('Palmeiras', 'Plameiras-SP'))
# Out:
#      Horário      Dia        Data        Clube 1       Clube 2       Vencedor  \
# 0      16h00   Sábado  2000-07-29     Fluminense         Bahia     Fluminense
# 1      16h00   Sábado  2000-07-29          Vasco         Sport          Sport
# 2      16h00   Sábado  2000-07-29        Vitória  Plameiras-SP        Vitória
# 3      17h00  Domingo  2000-07-30    Botafogo-RJ   Atlético-MG              -
# 4      18h30  Domingo  2000-07-30      Juventude      Flamengo              -
# ...      ...      ...         ...            ...           ...            ...
# 7934   17:00  Domingo  2019-12-08          Goiás        Grêmio          Goiás
# 7935   17:00  Domingo  2019-12-08  Internacional   Atlético-MG  Internacional
# 7936   17:00  Domingo  2019-12-08       Cruzeiro  Plameiras-SP   Plameiras-SP
# 7937   17:00  Domingo  2019-12-08         Santos      Flamengo         Santos
# 7938   17:00  Domingo  2019-12-08            CSA     São Paulo      São Paulo
#
# ...

# %%
df2.columns
# Out:
# Index(['Horário', 'Dia', 'Data', 'Clube 1', 'Clube 2', 'Vencedor', 'Rodada',
#        'Arena', 'Clube 1 Gols', 'Clube 2 Gols', 'Clube 1 Estado',
#        'Clube 2 Estado', 'Estado Clube Vencedor', 'Resultado'],
#       dtype='object')
